# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tqdm import tqdm
import feather

# %%
from boto.s3.connection import S3Connection
from boto.s3.key import Key
import sys, os
import re
import json
from urllib.request import FancyURLopener
import cv2
import glob
import zipfile
from multiprocessing import Pool
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
from matplotlib import pyplot as plt
from sklearn import linear_model

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
KEY_FILE = '..//..//..//data//aws_keys//keys.txt'

f = open(KEY_FILE,'rb')
key_data = str(f.read())
keys = re.findall(pattern='\=([a-zA-Z0-9]*)',string=key_data)

AWS_KEY = keys[0]
AWS_SECRET = keys[1]

del keys

# %%
BUCKET = 'imaterialist-challenge'
PATH_TO_DATA = '..//..//..//data//imaterialist//'

# %%
labeldf = feather.read_dataframe(PATH_TO_DATA+'labeldf.feather')
task_df = feather.read_dataframe(PATH_TO_DATA+'taskdf.feather')
train_annotations = feather.read_dataframe(PATH_TO_DATA+'train_annotations.feather')

# %%
def readImageResized(imageId,size):
    return cv2.resize(cv2.imread(PATH_TO_DATA+imageId+'.jpg'),size)

# %%
Y_ = lambda x: 0.7*x + 110

# %%
Y_(475)
# Out:
# 442.5

# %%
size = (475,442)

# %%
def plotImageResized(image):
    plt.imshow(cv2.cvtColor(cv2.resize(image, size), cv2.COLOR_BGR2RGB))
    plt.show()

# %%
def GetImageResized(imageId):
    try:
        appended = [imageId,readImageResized(imageId,(475,442))]
        return(appended)
    except:
        x = 1

# %%
train_images = []

# %%
imageList = list(train_annotations['imageId'])
#np.random.shuffle(imageList)

# %%
pool = Pool()
pool.map_async(GetImageResized, imageList, callback = train_images.append )
pool.close()
pool.join()

# %%
train_images = train_images[0]

# %%
train_images[:20]
# Out:
# [['1', array([[[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          [[255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
# ...

# %%
task_df
# Out:
#    taskId                 taskName taskName_type   taskName_subtype
# 0       1              shoe:gender          shoe             gender
# 1       2                 shoe:age          shoe                age
# 2       3               shoe:color          shoe              color
# 3       4           shoe:up height          shoe          up height
# 4       5         dress:decoration         dress         decoration
# 5       6              dress:color         dress              color
# 6       7           dress:material         dress           material
# 7       8         dress:silhouette         dress         silhouette
# 8       9                shoe:type          shoe               type
# 9      10        shoe:closure type          shoe       closure type
# 10     11              pants:color         pants              color
# 11     12             dress:length         dress             length
# 12     13           outerwear:type     outerwear               type
# ...

# %%
np.unique(task_df['taskName_type'])
# Out:
# array(['dress', 'outerwear', 'pants', 'shoe'], dtype=object)

# %%
np.unique(task_df[task_df['taskName_type'] == 'pants']['taskName_subtype'])
# Out:
# array(['age', 'color', 'decoration', 'fit', 'gender', 'length', 'material',
#        'pattern', 'rise type', 'type'], dtype=object)

# %%
train_data = pd.merge(pd.merge( train_annotations, task_df, on='taskId' ), labeldf, on = 'labelId')

# %%
train_data[train_data['imageId'] == '39406']
# Out:
#       imageId labelId taskId         taskName taskName_type taskName_subtype  \
# 13093   39406      38     17  outerwear:color     outerwear            color
# 41228   39406      12     11      pants:color         pants            color
#
#       labelName
# 13093     khaki
# 41228     light

# %%
train_data.groupby('imageId', as_index=True)[['taskName_type']].nunique().sort_values('taskName_type', ascending = False).head(5)
# Out:
#          taskName_type
# imageId
# 39406                2
# 37654                2
# 15601                2
# 292                  2
# 27113                2

# %% [markdown]
# # Maybe build seperate models for each taskName_type...

# %% [markdown]
# # start with pants gender

# %%
pants_gender_set = set(list(train_data[(train_data['taskName_type'] == 'pants') & (train_data['taskName_subtype'] == 'gender')]['imageId']))

# %%
train_images = [ image for image in train_images if image != None ]

# %%
train_image_frame = pd.DataFrame([ image for image in train_images if image[0] in pants_gender_set])

# %%
train_image_frame.columns = ['imageId','imageData']

# %%
train_image_frame.drop_duplicates('imageId')

# %%
train_image_frame.head(5)
# Out:
#      0                                                  1
# 0   86  [[[174, 214, 239], [172, 212, 237], [171, 211,...
# 1   86  [[[174, 214, 239], [172, 212, 237], [171, 211,...
# 2   86  [[[174, 214, 239], [172, 212, 237], [171, 211,...
# 3   86  [[[174, 214, 239], [172, 212, 237], [171, 211,...
# 4  105  [[[238, 238, 238], [238, 238, 238], [238, 238,...
